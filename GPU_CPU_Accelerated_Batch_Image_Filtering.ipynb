# %% [markdown]
# <a href="https://colab.research.google.com/github/aakanksha-27/GPU-CPU-Accelerated-Batch-Image-Filtering/blob/main/GPU_CPU_Accelerated_Batch_Image_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/aakanksha-27/GPU-CPU-Accelerated-Batch-Image-Filtering.git
# Out:
# Cloning into 'GPU-CPU-Accelerated-Batch-Image-Filtering'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 6.97 KiB | 2.32 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd GPU-CPU-Accelerated-Batch-Image-Filtering
# !ls
# Out:
# /content/GPU-CPU-Accelerated-Batch-Image-Filtering
# README.md  run.sh  src

# %%
# !pip install cupy-cuda12x opencv-python matplotlib numpy

# %%
import cupy as cp
cp.cuda.runtime.getDeviceCount()
# Out:
# 1

# %%
# !nvidia-smi
# Out:
# Tue Dec 16 10:20:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install torchvision

# %%
from torchvision import datasets
from torchvision.transforms import ToTensor
import os
import numpy as np
from PIL import Image

os.makedirs("data/input", exist_ok=True)

dataset = datasets.MNIST(root="data", train=True, download=True)
for i in range(500):
    img, _ = dataset[i]
    img = img.resize((256, 256))
    img.save(f"data/input/img_{i}.png")
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.00MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 132kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.03MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.09MB/s]

# %%
# !chmod +x run.sh
# !./run.sh
# Out:
# Timing comparison complete.
